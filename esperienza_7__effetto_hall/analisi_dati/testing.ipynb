# %%
import setup_hall.linear_regression as lg
# Out:
# Welcome to JupyROOT 6.24/02

# %%
gen_i10mA = lg.linear_regression('generatore.txt', system='current',figsize=(800,550))

gen_i10mA.set_model_parameters(1000/500, 0)

gen_i10mA.showfig('GEN.0.10mA', optional_label='Generatore')
gen_i10mA.get_correlation_offset_parameter()
# Out:
# model results chi2/ndf (prob): 0.2796881563157294/9 (0.9999975624782381)
# correlation parameter: 1.7242(300) [arb. u.]
# offset: 0.0673(889) [coherent units with y-axis value]
# ((1.7241819129014446, 0.030037918506097314),
#  (0.0673130107832415, 0.08891822843062568))
# Applying ATLAS style settings
#  FCN=0.279688 FROM MIGRAD    STATUS=CONVERGED      50 CALLS          51 TOTAL
#                      EDM=7.59718e-13    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.72418e+00   3.00379e-02   8.48703e-06  -6.62704e-05
#    2  p1           6.73130e-02   8.89182e-02   2.51236e-05  -1.14248e-05
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: __figure__
# Info in <TCanvas::Print>: pdf file /Users/massimosotgia/Desktop/uni_at_DIFI/Lab2/esperienza_7__effetto_hall/fig/GEN.0.10mA.pdf has been created

# %%
op_amp_MC = lg.linear_regression(filename='guadagnoMC.txt', system='keithley',figsize=(800,550)) 

op_amp_MC.set_model_parameters(0,0)

op_amp_MC.showfig(statposition=(.25,.3), optional_label='G_{MC}', subfig_label='(a)', fmt='G_CM')
op_amp_MC.get_correlation_offset_parameter()
# Out:
# model results chi2/ndf (prob): 0.013301894806912375/5 (0.9999989196367114)
# correlation parameter: -0.01122(204) [arb. u.]
# offset: 0.00453(453) [coherent units with y-axis value]
# ((-0.011222615505091809, 0.002044611248277164),
#  (0.00452655343661498, 0.004532217888665849))
# Applying ATLAS style settings
#  FCN=0.0133019 FROM MIGRAD    STATUS=CONVERGED      46 CALLS          47 TOTAL
#                      EDM=4.20218e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -1.12226e-02   2.04461e-03   4.52686e-07   9.10274e-02
#    2  p1           4.52655e-03   4.53222e-03   1.00350e-06  -2.45692e-02
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: __figure__
# Info in <TCanvas::Print>: pdf file /Users/massimosotgia/Desktop/uni_at_DIFI/Lab2/esperienza_7__effetto_hall/fig/G_CM.pdf has been created

# %%
op_amp_DIFF = lg.linear_regression(filename='guadagnoDIFF.txt', system='keithley',figsize=(800,550))
op_amp_DIFF.set_model_parameters(200, 0)
op_amp_DIFF.showfig(optional_label='G_{diff}', subfig_label='(b)', 
                    subfigposition=(.8,.4), fmt='G_diff')
op_amp_DIFF.get_correlation_offset_parameter()
# Out:
# model results chi2/ndf (prob): 0.27104059485739196/3 (0.9653796521342823)
# correlation parameter: 206.6(24.5) [arb. u.]
# offset: -1.495(866) [coherent units with y-axis value]
# ((206.55108584551905, 24.45009696134029),
#  (-1.4945602451358297, 0.8662129113203739))
# Applying ATLAS style settings
#  FCN=0.271041 FROM MIGRAD    STATUS=CONVERGED      53 CALLS          54 TOTAL
#                      EDM=4.59676e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.06551e+02   2.44501e+01   2.63094e-03  -6.14426e-05
#    2  p1          -1.49456e+00   8.66213e-01   9.32122e-05  -1.78704e-03
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: __figure__
# Info in <TCanvas::Print>: pdf file /Users/massimosotgia/Desktop/uni_at_DIFI/Lab2/esperienza_7__effetto_hall/fig/G_diff.pdf has been created
